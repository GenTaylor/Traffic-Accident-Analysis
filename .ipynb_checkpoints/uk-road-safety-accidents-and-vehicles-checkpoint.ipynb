# %%
#Import modules
import numpy as np
import holidays
import pandas as pd
import datetime
import sklearn
import scipy
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV
import seaborn as sns
import math
from sklearn.model_selection import cross_val_score
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
df1 = pd.read_csv(r'Accident_Information.csv')
df2 = pd.read_csv(r'Vehicle_Information.csv')

# %%
print(df1.columns)
print(df2.columns)
# Out:
# Index(['Accident_Index', '1st_Road_Class', '1st_Road_Number', '2nd_Road_Class',
#        '2nd_Road_Number', 'Accident_Severity', 'Carriageway_Hazards', 'Date',
#        'Day_of_Week', 'Did_Police_Officer_Attend_Scene_of_Accident',
#        'Junction_Control', 'Junction_Detail', 'Latitude', 'Light_Conditions',
#        'Local_Authority_(District)', 'Local_Authority_(Highway)',
#        'Location_Easting_OSGR', 'Location_Northing_OSGR', 'Longitude',
#        'LSOA_of_Accident_Location', 'Number_of_Casualties',
#        'Number_of_Vehicles', 'Pedestrian_Crossing-Human_Control',
#        'Pedestrian_Crossing-Physical_Facilities', 'Police_Force',
#        'Road_Surface_Conditions', 'Road_Type', 'Special_Conditions_at_Site',
#        'Speed_limit', 'Time', 'Urban_or_Rural_Area', 'Weather_Conditions',
#        'Year', 'InScotland'],
#       dtype='object')
# Index(['Accident_Index', 'Age_Band_of_Driver', 'Age_of_Vehicle',
#        'Driver_Home_Area_Type', 'Driver_IMD_Decile', 'Engine_Capacity_.CC.',
#        'Hit_Object_in_Carriageway', 'Hit_Object_off_Carriageway',
#        'Journey_Purpose_of_Driver', 'Junction_Location', 'make', 'model',
#        'Propulsion_Code', 'Sex_of_Driver', 'Skidding_and_Overturning',
#        'Towing_and_Articulation', 'Vehicle_Leaving_Carriageway',
#        'Vehicle_Location.Restricted_Lane', 'Vehicle_Manoeuvre',
#        'Vehicle_Reference', 'Vehicle_Type', 'Was_Vehicle_Left_Hand_Drive',
#        'X1st_Point_of_Impact', 'Year'],
#       dtype='object')

# %%
print("df1 shape:", df1.shape)
print("df2 shape:", df2.shape)
# Out:
# df1 shape: (2047256, 34)
# df2 shape: (2177205, 24)

# %%
df3 = df1.merge(df2, on='Accident_Index')

# %%
df3.head()
# Out:
#   Accident_Index 1st_Road_Class  1st_Road_Number 2nd_Road_Class  \
# 0  200501BS00002              B            450.0              C
# 1  200501BS00003              C              0.0            NaN
# 2  200501BS00004              A           3220.0            NaN
# 3  200501BS00005   Unclassified              0.0            NaN
# 4  200501BS00006   Unclassified              0.0            NaN
#
#    2nd_Road_Number Accident_Severity Carriageway_Hazards        Date  \
# 0              0.0            Slight                None  2005-01-05
# 1              0.0            Slight                None  2005-01-06
# 2              0.0            Slight                None  2005-01-07
# 3              0.0            Slight                None  2005-01-10
# 4              0.0            Slight                None  2005-01-11
#
#   Day_of_Week  Did_Police_Officer_Attend_Scene_of_Accident  ...  \
# 0   Wednesday                                          1.0  ...
# 1    Thursday                                          1.0  ...
# 2      Friday                                          1.0  ...
# 3      Monday                                          1.0  ...
# 4     Tuesday                                          1.0  ...
#
#   Skidding_and_Overturning Towing_and_Articulation  \
# 0                     None     No tow/articulation
# 1                     None     No tow/articulation
# 2                     None     No tow/articulation
# 3                  Skidded     No tow/articulation
# 4                     None     No tow/articulation
#
#    Vehicle_Leaving_Carriageway Vehicle_Location.Restricted_Lane  \
# 0    Did not leave carriageway                              0.0
# 1    Did not leave carriageway                              0.0
# 2    Did not leave carriageway                              0.0
# 3    Did not leave carriageway                              0.0
# 4    Did not leave carriageway                              0.0
#
#              Vehicle_Manoeuvre Vehicle_Reference  \
# 0          Slowing or stopping                 1
# 1  Going ahead right-hand bend                 1
# 2            Going ahead other                 1
# 3            Going ahead other                 1
# 4                   Moving off                 1
#
#                            Vehicle_Type  Was_Vehicle_Left_Hand_Drive  \
# 0  Bus or coach (17 or more pass seats)                           No
# 1  Bus or coach (17 or more pass seats)                           No
# 2                                   Car                           No
# 3            Motorcycle 125cc and under                           No
# 4                                   Car                           No
#
#    X1st_Point_of_Impact Year_y
# 0              Nearside   2005
# 1              Nearside   2005
# 2                 Front   2005
# 3                 Front   2005
# 4        Did not impact   2005
#
# [5 rows x 57 columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2058408 entries, 0 to 2058407
# Data columns (total 57 columns):
# Accident_Index                                 object
# 1st_Road_Class                                 object
# 1st_Road_Number                                float64
# 2nd_Road_Class                                 object
# 2nd_Road_Number                                float64
# Accident_Severity                              object
# Carriageway_Hazards                            object
# Date                                           object
# Day_of_Week                                    object
# Did_Police_Officer_Attend_Scene_of_Accident    float64
# Junction_Control                               object
# Junction_Detail                                object
# Latitude                                       float64
# Light_Conditions                               object
# Local_Authority_(District)                     object
# Local_Authority_(Highway)                      object
# Location_Easting_OSGR                          float64
# Location_Northing_OSGR                         float64
# Longitude                                      float64
# LSOA_of_Accident_Location                      object
# Number_of_Casualties                           int64
# Number_of_Vehicles                             int64
# Pedestrian_Crossing-Human_Control              float64
# Pedestrian_Crossing-Physical_Facilities        float64
# Police_Force                                   object
# Road_Surface_Conditions                        object
# Road_Type                                      object
# Special_Conditions_at_Site                     object
# Speed_limit                                    float64
# Time                                           object
# Urban_or_Rural_Area                            object
# Weather_Conditions                             object
# Year_x                                         int64
# InScotland                                     object
# Age_Band_of_Driver                             object
# Age_of_Vehicle                                 float64
# Driver_Home_Area_Type                          object
# Driver_IMD_Decile                              float64
# Engine_Capacity_.CC.                           float64
# Hit_Object_in_Carriageway                      object
# Hit_Object_off_Carriageway                     object
# Journey_Purpose_of_Driver                      object
# Junction_Location                              object
# make                                           object
# model                                          object
# Propulsion_Code                                object
# Sex_of_Driver                                  object
# Skidding_and_Overturning                       object
# Towing_and_Articulation                        object
# Vehicle_Leaving_Carriageway                    object
# Vehicle_Location.Restricted_Lane               float64
# Vehicle_Manoeuvre                              object
# Vehicle_Reference                              int64
# Vehicle_Type                                   object
# Was_Vehicle_Left_Hand_Drive                    object
# X1st_Point_of_Impact                           object
# Year_y                                         int64
# dtypes: float64(14), int64(5), object(38)
# memory usage: 910.9+ MB

# %%
print("df3 shape:",df3.shape)
# Out:
# df3 shape: (2058408, 57)

# %%
df3.isnull().sum().sort_values(ascending=False)/2058408*100
# Out:
# 2nd_Road_Class                                 40.222201
# Driver_IMD_Decile                              33.486559
# Age_of_Vehicle                                 16.418611
# model                                          14.543132
# Engine_Capacity_.CC.                           12.160709
# Propulsion_Code                                11.348479
# LSOA_of_Accident_Location                       6.762848
# make                                            5.384987
# 2nd_Road_Number                                 0.919497
# Pedestrian_Crossing-Physical_Facilities         0.066556
# Vehicle_Location.Restricted_Lane                0.054605
# Pedestrian_Crossing-Human_Control               0.031772
# Time                                            0.007093
# Longitude                                       0.006073
# Location_Easting_OSGR                           0.006024
# Location_Northing_OSGR                          0.006024
# Latitude                                        0.006024
# Did_Police_Officer_Attend_Scene_of_Accident     0.005538
# Speed_limit                                     0.003158
# InScotland                                      0.002138
# 1st_Road_Number                                 0.000049
# Junction_Control                                0.000000
# Light_Conditions                                0.000000
# Day_of_Week                                     0.000000
# Local_Authority_(District)                      0.000000
# Local_Authority_(Highway)                       0.000000
# Date                                            0.000000
# Carriageway_Hazards                             0.000000
# Accident_Severity                               0.000000
# 1st_Road_Class                                  0.000000
# Number_of_Casualties                            0.000000
# Number_of_Vehicles                              0.000000
# Junction_Detail                                 0.000000
# Year_y                                          0.000000
# Police_Force                                    0.000000
# Journey_Purpose_of_Driver                       0.000000
# Was_Vehicle_Left_Hand_Drive                     0.000000
# Vehicle_Type                                    0.000000
# Vehicle_Reference                               0.000000
# Vehicle_Manoeuvre                               0.000000
# Vehicle_Leaving_Carriageway                     0.000000
# Towing_and_Articulation                         0.000000
# Skidding_and_Overturning                        0.000000
# Sex_of_Driver                                   0.000000
# Junction_Location                               0.000000
# Hit_Object_off_Carriageway                      0.000000
# Road_Surface_Conditions                         0.000000
# Hit_Object_in_Carriageway                       0.000000
# Driver_Home_Area_Type                           0.000000
# Age_Band_of_Driver                              0.000000
# Year_x                                          0.000000
# Weather_Conditions                              0.000000
# Urban_or_Rural_Area                             0.000000
# X1st_Point_of_Impact                            0.000000
# Special_Conditions_at_Site                      0.000000
# Road_Type                                       0.000000
# Accident_Index                                  0.000000
# dtype: float64

# %%
df3 = df3.drop(['2nd_Road_Class', 'Driver_IMD_Decile','Year_y'], axis=1)

df3 = df3.rename(columns={'Year_x':'Year'})

# %%
#standardize all columns to lowercase, and remove some characters 
#for ease of use in querying
df3.columns = map(str.lower, df3.columns)
df3.columns = df3.columns.str.replace('.','')
df3.columns = df3.columns.str.replace('(','')
df3.columns = df3.columns.str.replace(')','')
#verify
df3.columns
# Out:
# Index(['accident_index', '1st_road_class', '1st_road_number',
#        '2nd_road_number', 'accident_severity', 'carriageway_hazards', 'date',
#        'day_of_week', 'did_police_officer_attend_scene_of_accident',
#        'junction_control', 'junction_detail', 'latitude', 'light_conditions',
#        'local_authority_district', 'local_authority_highway',
#        'location_easting_osgr', 'location_northing_osgr', 'longitude',
#        'lsoa_of_accident_location', 'number_of_casualties',
#        'number_of_vehicles', 'pedestrian_crossing-human_control',
#        'pedestrian_crossing-physical_facilities', 'police_force',
#        'road_surface_conditions', 'road_type', 'special_conditions_at_site',
#        'speed_limit', 'time', 'urban_or_rural_area', 'weather_conditions',
#        'year', 'inscotland', 'age_band_of_driver', 'age_of_vehicle',
#        'driver_home_area_type', 'engine_capacity_cc',
#        'hit_object_in_carriageway', 'hit_object_off_carriageway',
#        'journey_purpose_of_driver', 'junction_location', 'make', 'model',
#        'propulsion_code', 'sex_of_driver', 'skidding_and_overturning',
#        'towing_and_articulation', 'vehicle_leaving_carriageway',
#        'vehicle_locationrestricted_lane', 'vehicle_manoeuvre',
#        'vehicle_reference', 'vehicle_type', 'was_vehicle_left_hand_drive',
#        'x1st_point_of_impact'],
#       dtype='object')

# %%
year = range(2005,2018)
uk_holidays = holidays.UnitedKingdom(years=year)

# %%
uk_holidays.years
# Out:
# {2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017}

# %%
ukh  = pd.DataFrame(list(uk_holidays.items()))

# %%
ukh.dtypes
# Out:
# 0    object
# 1    object
# dtype: object

# %%
ukh = ukh.rename(columns={0:"date", 1:"holiday"})

# %%
df = pd.concat([df3,ukh])

# %%
df.head()
# Out:
#   1st_road_class  1st_road_number  2nd_road_number accident_index  \
# 0              B            450.0              0.0  200501BS00002
# 1              C              0.0              0.0  200501BS00003
# 2              A           3220.0              0.0  200501BS00004
# 3   Unclassified              0.0              0.0  200501BS00005
# 4   Unclassified              0.0              0.0  200501BS00006
#
#   accident_severity age_band_of_driver  age_of_vehicle carriageway_hazards  \
# 0            Slight            36 - 45             3.0                None
# 1            Slight            26 - 35             5.0                None
# 2            Slight            46 - 55             4.0                None
# 3            Slight            46 - 55            10.0                None
# 4            Slight            46 - 55             1.0                None
#
#          date day_of_week  ...  urban_or_rural_area  \
# 0  2005-01-05   Wednesday  ...                Urban
# 1  2005-01-06    Thursday  ...                Urban
# 2  2005-01-07      Friday  ...                Urban
# 3  2005-01-10      Monday  ...                Urban
# 4  2005-01-11     Tuesday  ...                Urban
#
#   vehicle_leaving_carriageway  vehicle_locationrestricted_lane  \
# 0   Did not leave carriageway                              0.0
# 1   Did not leave carriageway                              0.0
# 2   Did not leave carriageway                              0.0
# 3   Did not leave carriageway                              0.0
# 4   Did not leave carriageway                              0.0
#
#              vehicle_manoeuvre vehicle_reference  \
# 0          Slowing or stopping               1.0
# 1  Going ahead right-hand bend               1.0
# 2            Going ahead other               1.0
# 3            Going ahead other               1.0
# 4                   Moving off               1.0
#
#                            vehicle_type was_vehicle_left_hand_drive  \
# 0  Bus or coach (17 or more pass seats)                          No
# 1  Bus or coach (17 or more pass seats)                          No
# 2                                   Car                          No
# 3            Motorcycle 125cc and under                          No
# 4                                   Car                          No
#
#       weather_conditions x1st_point_of_impact    year
# 0     Fine no high winds             Nearside  2005.0
# 1     Fine no high winds             Nearside  2005.0
# 2     Fine no high winds                Front  2005.0
# 3     Fine no high winds                Front  2005.0
# 4  Raining no high winds       Did not impact  2005.0
#
# [5 rows x 55 columns]

# %%
#Check Missing Data
df.isnull().sum().sort_values(ascending=False)
# Out:
# holiday                                        2058408
# age_of_vehicle                                  338152
# model                                           299547
# engine_capacity_cc                              250507
# propulsion_code                                 233788
# lsoa_of_accident_location                       139397
# make                                            111035
# 2nd_road_number                                  19117
# pedestrian_crossing-physical_facilities           1560
# vehicle_locationrestricted_lane                   1314
# pedestrian_crossing-human_control                  844
# time                                               336
# longitude                                          315
# latitude                                           314
# location_northing_osgr                             314
# location_easting_osgr                              314
# did_police_officer_attend_scene_of_accident        304
# speed_limit                                        255
# inscotland                                         234
# 1st_road_number                                    191
# journey_purpose_of_driver                          190
# junction_control                                   190
# junction_detail                                    190
# hit_object_in_carriageway                          190
# hit_object_off_carriageway                         190
# driver_home_area_type                              190
# day_of_week                                        190
# carriageway_hazards                                190
# age_band_of_driver                                 190
# accident_severity                                  190
# accident_index                                     190
# junction_location                                  190
# year                                               190
# light_conditions                                   190
# local_authority_district                           190
# weather_conditions                                 190
# was_vehicle_left_hand_drive                        190
# vehicle_type                                       190
# vehicle_reference                                  190
# vehicle_manoeuvre                                  190
# vehicle_leaving_carriageway                        190
# urban_or_rural_area                                190
# towing_and_articulation                            190
# special_conditions_at_site                         190
# skidding_and_overturning                           190
# sex_of_driver                                      190
# road_type                                          190
# road_surface_conditions                            190
# police_force                                       190
# number_of_vehicles                                 190
# number_of_casualties                               190
# x1st_point_of_impact                               190
# local_authority_highway                            190
# 1st_road_class                                     190
# date                                                 0
# dtype: int64

# %%
df['holiday'].fillna("Non-Holiday", inplace=True)
df = df.dropna(subset=['accident_index'])

# %%
print('df shape', df.shape)
# Out:
# df shape (2058408, 55)

# %%
#Check Missing Data
df.isnull().sum().sort_values(ascending=False)/2058598*100
# Out:
# age_of_vehicle                                 16.417096
# model                                          14.541790
# engine_capacity_cc                             12.159586
# propulsion_code                                11.347432
# lsoa_of_accident_location                       6.762224
# make                                            5.384490
# 2nd_road_number                                 0.919412
# pedestrian_crossing-physical_facilities         0.066550
# vehicle_locationrestricted_lane                 0.054600
# pedestrian_crossing-human_control               0.031769
# time                                            0.007092
# longitude                                       0.006072
# latitude                                        0.006024
# location_easting_osgr                           0.006024
# location_northing_osgr                          0.006024
# did_police_officer_attend_scene_of_accident     0.005538
# speed_limit                                     0.003157
# inscotland                                      0.002137
# 1st_road_number                                 0.000049
# accident_severity                               0.000000
# junction_detail                                 0.000000
# junction_control                                0.000000
# journey_purpose_of_driver                       0.000000
# accident_index                                  0.000000
# holiday                                         0.000000
# day_of_week                                     0.000000
# age_band_of_driver                              0.000000
# carriageway_hazards                             0.000000
# hit_object_off_carriageway                      0.000000
# date                                            0.000000
# hit_object_in_carriageway                       0.000000
# driver_home_area_type                           0.000000
# junction_location                               0.000000
# year                                            0.000000
# light_conditions                                0.000000
# special_conditions_at_site                      0.000000
# weather_conditions                              0.000000
# was_vehicle_left_hand_drive                     0.000000
# vehicle_type                                    0.000000
# vehicle_reference                               0.000000
# vehicle_manoeuvre                               0.000000
# vehicle_leaving_carriageway                     0.000000
# urban_or_rural_area                             0.000000
# towing_and_articulation                         0.000000
# skidding_and_overturning                        0.000000
# local_authority_district                        0.000000
# sex_of_driver                                   0.000000
# road_type                                       0.000000
# road_surface_conditions                         0.000000
# police_force                                    0.000000
# number_of_vehicles                              0.000000
# number_of_casualties                            0.000000
# x1st_point_of_impact                            0.000000
# local_authority_highway                         0.000000
# 1st_road_class                                  0.000000
# dtype: float64

# %%
#Checking the unique values for 'age_of_vehicle'
print("Distinct values for age_of_vehicle:\n", set(df['age_of_vehicle']))
